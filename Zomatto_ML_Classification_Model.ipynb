# %% [markdown]
# #**Import Libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#import gdown

#from google.colab import files

#url = f"https://drive.google.com/uc?id=1-B3C1F1fzYb-tqseby07pGu-AoDo0Yj4&export=download"
#output = "zomato.csv"

# Download the file
#gdown.download(url, output, quiet=False)

# %% [markdown]
# # Read & Explore Data

# %%
df=pd.read_csv("zomato.csv", encoding = 'latin_1')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.describe(include='object')
# Out:
#                                                       url        address  \
# count                                               51717          51717
# unique                                              51717          11495
# top     https://www.zomato.com/bangalore/jalsa-banasha...  Delivery Only
# freq                                                    1            128
#
#                    name online_order book_table   rate         phone location  \
# count             51717        51717      51717  43942         50509    51696
# unique             8792            2          2     64         14926       93
# top     Cafe Coffee Day          Yes         No    NEW  080 43334321      BTM
# freq                 96        30444      45268   2208           216     5124
#
#           rest_type dish_liked      cuisines approx_cost(for two people)  \
# count         51490      23639         51672                       51371
# ...

# %%
df.nunique()
# Out:
# url                            51717
# address                        11495
# name                            8792
# online_order                       2
# book_table                         2
# rate                              64
# votes                           2328
# phone                          14926
# location                          93
# rest_type                         93
# dish_liked                      5271
# cuisines                        2723
# approx_cost(for two people)       70
# reviews_list                   22513
# menu_item                       9098
# listed_in(type)                    7
# listed_in(city)                   30
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           15.033741
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %% [markdown]
# # Data Cleanining
#
# 1.   Adjust Columns names
# 2.   Adjust Columns Type
# 3.   Drop redundant Columns
# 4.   Remove Duplicates

# %% [markdown]
# ## 1.Adjust Columns Names

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.rename(columns={'approx_cost(for two people)': 'couple_cost',
                   'listed_in(type)': 'listed_type',
                   'listed_in(city)':'city'}, inplace=True)

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'couple_cost', 'reviews_list', 'menu_item', 'listed_type', 'city'],
#       dtype='object')

# %% [markdown]
# ## 2.Adjust Columns Types

# %% [markdown]
# ### a. couple_cost

# %%
df['couple_cost'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', nan, '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
df['couple_cost']=df['couple_cost'].apply(lambda x: np.nan if x == '' else float(str(x).replace(',', '')))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           51717 non-null  object
#  1   address       51717 non-null  object
#  2   name          51717 non-null  object
#  3   online_order  51717 non-null  object
#  4   book_table    51717 non-null  object
#  5   rate          43942 non-null  object
#  6   votes         51717 non-null  int64
#  7   phone         50509 non-null  object
#  8   location      51696 non-null  object
#  9   rest_type     51490 non-null  object
#  10  dish_liked    23639 non-null  object
#  11  cuisines      51672 non-null  object
#  12  couple_cost   51371 non-null  float64
#  13  reviews_list  51717 non-null  object
#  14  menu_item     51717 non-null  object
#  15  listed_type   51717 non-null  object
#  16  city          51717 non-null  object
# dtypes: float64(1), int64(1), object(15)
# ...

# %%
df.couple_cost.unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         900.,  200.,  750.,  150.,  850.,  100., 1200.,  350.,  250.,
#         950., 1000., 1500., 1300.,  199.,   80., 1100.,  160., 1600.,
#         230.,  130.,   50.,  190., 1700.,   nan, 1400.,  180., 1350.,
#        2200., 2000., 1800., 1900.,  330., 2500., 2100., 3000., 2800.,
#        3400.,   40., 1250., 3500., 4000., 2400., 2600.,  120., 1450.,
#         469.,   70., 3200.,   60.,  560.,  240.,  360., 6000., 1050.,
#        2300., 4100., 5000., 3700., 1650., 2700., 4500.,  140.])

# %% [markdown]
# ### b. rate

# %%
df.rate.unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
len(df[df['rate']=='NEW'])
# Out:
# 2208

# %%
len(df[df['rate'].isnull()])
# Out:
# 7775

# %%
df['rate']= df['rate'].apply(lambda x: np.nan if x == 'NEW' or x == '' or x =='-' else float(str(x).split('/')[0]))

# %%
df.rate.unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, nan, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   url           51717 non-null  object
#  1   address       51717 non-null  object
#  2   name          51717 non-null  object
#  3   online_order  51717 non-null  object
#  4   book_table    51717 non-null  object
#  5   rate          41665 non-null  float64
#  6   votes         51717 non-null  int64
#  7   phone         50509 non-null  object
#  8   location      51696 non-null  object
#  9   rest_type     51490 non-null  object
#  10  dish_liked    23639 non-null  object
#  11  cuisines      51672 non-null  object
#  12  couple_cost   51371 non-null  float64
#  13  reviews_list  51717 non-null  object
#  14  menu_item     51717 non-null  object
#  15  listed_type   51717 non-null  object
#  16  city          51717 non-null  object
# dtypes: float64(2), int64(1), object(14)
# ...

# %% [markdown]
# ## 3.Drop Redundant Columns

# %% [markdown]
# ### a. numerical columns check

# %%
num_cols = df.select_dtypes(exclude=['object'])
num_cols
# Out:
#        rate  votes  couple_cost
# 0       4.1    775        800.0
# 1       4.1    787        800.0
# 2       3.8    918        800.0
# 3       3.7     88        300.0
# 4       3.8    166        600.0
# ...     ...    ...          ...
# 51712   3.6     27       1500.0
# 51713   NaN      0        600.0
# 51714   NaN      0       2000.0
# 51715   4.3    236       2500.0
# 51716   3.4     13       1500.0
#
# [51717 rows x 3 columns]

# %%
num_cols.corr()
# Out:
#                  rate     votes  couple_cost
# rate         1.000000  0.434040     0.385183
# votes        0.434040  1.000000     0.381804
# couple_cost  0.385183  0.381804     1.000000

# %%
sns.heatmap(num_cols.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### b. categorical columns check
#
#
# We will firstly drop url, address, reviews_list, menu_item and phone

# %%
df.drop(['url', 'address', 'phone', 'reviews_list', 'menu_item'], axis=1, inplace=True)

# %%
df.groupby(['city','location'])['location'].count()
# Out:
# city        location
# BTM         BTM                              1130
#             Banashankari                        1
#             Bannerghatta Road                 254
#             Bommanahalli                       74
#             CV Raman Nagar                      1
#                                              ...
# Whitefield  KR Puram                           17
#             Marathahalli                       12
#             Old Airport Road                    1
#             Varthur Main Road, Whitefield      26
#             Whitefield                       1399
# Name: location, Length: 707, dtype: int64

# %% [markdown]
# It seems that keeping both *city* and *location* columns can generate useful business insights

# %%
df.groupby(['listed_type','rest_type'])['rest_type'].count()
# Out:
# listed_type    rest_type
# Buffet         Bar                        13
#                Bar, Casual Dining          7
#                Cafe                        3
#                Cafe, Casual Dining         3
#                Cafe, Lounge                5
#                                           ..
# Pubs and bars  Pub, Bar                    6
#                Pub, Cafe                   5
#                Pub, Casual Dining         44
#                Pub, Microbrewery          20
#                Sweet Shop, Quick Bites     1
# Name: rest_type, Length: 310, dtype: int64

# %% [markdown]
# The same applies for the *listed_type* and *rest_type*

# %% [markdown]
# ## 4.Removing Duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
#                         name online_order book_table  rate  votes  \
# 553             My Tea House          Yes        Yes   NaN      0
# 596             My Tea House          Yes        Yes   NaN      0
# 2195              Shiv Sagar           No         No   3.6     10
# 2235              Shiv Sagar           No         No   3.6     10
# 3747   The Fisherman's Wharf          Yes        Yes   4.4   4099
# ...                      ...          ...        ...   ...    ...
# 50366         House Of Candy          Yes         No   NaN      0
# 50379         House Of Candy          Yes         No   NaN      0
# 50405         House Of Candy          Yes         No   NaN      0
# 50900       Nawab Di Biryani          Yes         No   NaN      0
# 50904       Nawab Di Biryani          Yes         No   NaN      0
#
#                 location           rest_type  \
# 553         Banashankari       Casual Dining
# 596         Banashankari       Casual Dining
# ...

# %%
df = df.drop_duplicates(keep='first')

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, online_order, book_table, rate, votes, location, rest_type, dish_liked, cuisines, couple_cost, listed_type, city]
# Index: []

# %%
df.shape
# Out:
# (51609, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51609 entries, 0 to 51716
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          51609 non-null  object
#  1   online_order  51609 non-null  object
#  2   book_table    51609 non-null  object
#  3   rate          41590 non-null  float64
#  4   votes         51609 non-null  int64
#  5   location      51588 non-null  object
#  6   rest_type     51382 non-null  object
#  7   dish_liked    23595 non-null  object
#  8   cuisines      51564 non-null  object
#  9   couple_cost   51265 non-null  float64
#  10  listed_type   51609 non-null  object
#  11  city          51609 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 5.1+ MB

# %%
df.describe()
# Out:
#                rate         votes   couple_cost
# count  41590.000000  51609.000000  51265.000000
# mean       3.700142    283.283361    555.170682
# std        0.440451    803.282771    438.587661
# min        1.800000      0.000000     40.000000
# 25%        3.400000      7.000000    300.000000
# 50%        3.700000     41.000000    400.000000
# 75%        4.000000    198.000000    650.000000
# max        4.900000  16832.000000   6000.000000

# %%
df.describe(include='object')
# Out:
#                    name online_order book_table location    rest_type  \
# count             51609        51609      51609    51588        51382
# unique             8792            2          2       93           93
# top     Cafe Coffee Day          Yes         No      BTM  Quick Bites
# freq                 96        30361      45193     5109        19096
#
#        dish_liked      cuisines listed_type   city
# count       23595         51564       51609  51609
# unique       5271          2723           7     30
# top       Biryani  North Indian    Delivery    BTM
# freq          182          2907       25867   3266

# %%
df.isnull().mean()*100
# Out:
# name             0.000000
# online_order     0.000000
# book_table       0.000000
# rate            19.413281
# votes            0.000000
# location         0.040691
# rest_type        0.439846
# dish_liked      54.281230
# cuisines         0.087194
# couple_cost      0.666550
# listed_type      0.000000
# city             0.000000
# dtype: float64

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariate Analysis

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'dish_liked', 'cuisines', 'couple_cost', 'listed_type',
#        'city'],
#       dtype='object')

# %% [markdown]
# ### a. name

# %%
df['name'].unique()
# Out:
# array(['Jalsa', 'Spice Elephant', 'San Churro Cafe', ..., 'Nawabs Empire',
#        'SeeYa Restaurant',
#        'Plunge - Sheraton Grand Bengaluru Whitefield Hotel &...'],
#       dtype=object)

# %%
#top 10 restaurants in terms of branches
df['name'].value_counts().head(10)
# Out:
# name
# Cafe Coffee Day      96
# Onesta               85
# Just Bake            73
# Empire Restaurant    71
# Five Star Chicken    70
# Kanti Sweets         68
# Petoo                66
# Polar Bear           65
# Baskin Robbins       64
# Chef Baker's         62
# Name: count, dtype: int64

# %%
sns.barplot(df['name'].value_counts().head(10));
plt.title("Most Prevalent Restaurants")
plt.xticks(rotation=75);

# %% [markdown]
# ### b. online_order

# %%
df['online_order'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['online_order'].isnull().sum()
# Out:
# 0

# %%
df['online_order'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.title("Online Orders %")
plt.show()

# %%
sns.countplot(x='online_order', data=df)
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
df.groupby('online_order')['online_order'].count().sort_values(ascending=False)
# Out:
# online_order
# Yes    30361
# No     21248
# Name: online_order, dtype: int64

# %% [markdown]
# ### c. book_table

# %%
df['book_table'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['book_table'].isnull().sum()*100
# Out:
# 0

# %%
df['book_table'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.title("Booked Tables %")
plt.show()

# %%
sns.countplot(x='book_table', data=df);

# %%
df.groupby('book_table')['book_table'].count().sort_values(ascending=False)
# Out:
# book_table
# No     45193
# Yes     6416
# Name: book_table, dtype: int64

# %% [markdown]
# ### d. rate

# %%
df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, nan, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
sns.histplot(x='rate', data=df, kde=True);

# %%
sns.boxplot(x='rate', data=df);

# %%
sns.boxplot(x='rate', data=df);
sns.stripplot(x='rate', data=df, color='gray');

# %%
sns.violinplot(x='rate', data=df);

# %%
df['rate'].value_counts().head(10)
# Out:
# rate
# 3.9    3967
# 3.8    3870
# 3.7    3814
# 3.6    3311
# 4.0    3180
# 4.1    2942
# 3.5    2781
# 3.4    2472
# 3.3    2305
# 4.2    2179
# Name: count, dtype: int64

# %% [markdown]
# ### e. votes

# %%
df['votes'].unique()
# Out:
# array([ 775,  787,  918, ..., 4957, 2382,  843], dtype=int64)

# %%
len(df['votes'].unique())
# Out:
# 2328

# %%
sns.histplot(x='votes', data=df, kde=True);

# %%
df['votes'].max()
# Out:
# 16832

# %%
sns.boxplot(x='votes', data=df);
sns.stripplot(x='votes', data=df, color = 'gray', alpha=0.1);

# %%
df['votes'].describe()
# Out:
# count    51609.000000
# mean       283.283361
# std        803.282771
# min          0.000000
# 25%          7.000000
# 50%         41.000000
# 75%        198.000000
# max      16832.000000
# Name: votes, dtype: float64

# %%
sns.histplot(x='votes', data=df, kde=True);
plt.xlim(-100, 500);

# %%
sns.boxplot(x='votes', data=df);
plt.xlim(-100, 1000);

# %%
q1_votes = df['votes'].quantile(0.25)
q3_votes = df['votes'].quantile(0.75)
iqr_votes = q3_votes - q1_votes
upper_bound_votes = q3_votes + 1.5 * iqr_votes
len(df[df['votes'] >= upper_bound_votes])/len(df)*100
# Out:
# 13.437578716890464

# %% [markdown]
# The number of values above the upper bound of our 5 number summary represents more than 13% of the data which is a significant value to be neglected or ignored.

# %% [markdown]
# ### f. location

# %%
df['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Nagarbhavi', 'Bannerghatta Road', 'BTM', 'Kanakapura Road',
#        'Bommanahalli', nan, 'CV Raman Nagar', 'Electronic City', 'HSR',
#        'Marathahalli', 'Sarjapur Road', 'Wilson Garden', 'Shanti Nagar',
#        'Koramangala 5th Block', 'Koramangala 8th Block', 'Richmond Road',
#        'Koramangala 7th Block', 'Jalahalli', 'Koramangala 4th Block',
#        'Bellandur', 'Whitefield', 'East Bangalore', 'Old Airport Road',
#        'Indiranagar', 'Koramangala 1st Block', 'Frazer Town', 'RT Nagar',
#        'MG Road', 'Brigade Road', 'Lavelle Road', 'Church Street',
#        'Ulsoor', 'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road',
# ...

# %%
df['location'].value_counts().head(10)
# Out:
# location
# BTM                      5109
# HSR                      2521
# Koramangala 5th Block    2502
# JP Nagar                 2234
# Whitefield               2140
# Indiranagar              2075
# Jayanagar                1926
# Marathahalli             1843
# Bannerghatta Road        1628
# Bellandur                1283
# Name: count, dtype: int64

# %%
sns.barplot(df['location'].value_counts().head(10), orient='h');
plt.title("Top 10 Dense Locations");
plt.xlabel('');
plt.ylabel('');

# %% [markdown]
# ### g. rest_type

# %%
df['rest_type'].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', nan, 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
# ...

# %%
df[['rest_type', 'listed_type']]
# Out:
#                  rest_type    listed_type
# 0            Casual Dining         Buffet
# 1            Casual Dining         Buffet
# 2      Cafe, Casual Dining         Buffet
# 3              Quick Bites         Buffet
# 4            Casual Dining         Buffet
# ...                    ...            ...
# 51712                  Bar  Pubs and bars
# 51713                  Bar  Pubs and bars
# 51714                  Bar  Pubs and bars
# 51715                  Bar  Pubs and bars
# 51716   Bar, Casual Dining  Pubs and bars
#
# [51609 rows x 2 columns]

# %%
df['subtype'] = df['rest_type'].apply(lambda x: str(x).split(', ')[1] if ',' in str(x)  else np.nan)

# %%
df['subtype'].unique()
# Out:
# array([nan, 'Casual Dining', 'Cafe', 'Quick Bites', 'Dessert Parlor',
#        'Delivery', 'Beverage Shop', 'Sweet Shop', 'Bar', 'Bakery', 'Pub',
#        'Microbrewery', 'Food Court', 'Irani Cafee', 'Lounge', 'Kiosk',
#        'Mess', 'Meat Shop'], dtype=object)

# %%
df['rest_type'].apply(lambda x: str(x).split(', ')[0] if ',' in str(x)  else x).unique()
# Out:
# array(['Casual Dining', 'Cafe', 'Quick Bites', 'Delivery', 'Mess',
#        'Dessert Parlor', 'Bakery', 'Pub', 'Takeaway', 'Fine Dining',
#        'Beverage Shop', 'Sweet Shop', 'Bar', 'Confectionery', 'Kiosk',
#        'Food Truck', 'Microbrewery', 'Lounge', 'Food Court', nan, 'Dhaba',
#        'Club', 'Bhojanalya', 'Pop Up'], dtype=object)

# %%
df['rest_type'] = df['rest_type'].apply(lambda x: str(x).split(', ')[0] if ',' in str(x)  else x)
df[['rest_type', 'subtype']]
# Out:
#            rest_type        subtype
# 0      Casual Dining            NaN
# 1      Casual Dining            NaN
# 2               Cafe  Casual Dining
# 3        Quick Bites            NaN
# 4      Casual Dining            NaN
# ...              ...            ...
# 51712            Bar            NaN
# 51713            Bar            NaN
# 51714            Bar            NaN
# 51715            Bar            NaN
# 51716            Bar  Casual Dining
#
# [51609 rows x 2 columns]

# %%
sns.barplot(df['rest_type'].value_counts().head(10), orient='h');
plt.title("Top 10 Popular Types");
plt.xlabel('');
plt.ylabel('');

# %%
sns.barplot(df['subtype'].value_counts().head(10), orient='h');
plt.title("Top 10 Business Supporting Subtypes");
plt.xlabel('');
plt.ylabel('');

# %% [markdown]
# ### h. dish_liked

# %%
df['dish_liked'].unique()
# Out:
# array(['Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup',
#        'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#        'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#        ...,
#        'Noodles, Chicken Noodle, Momos, American Chopsuey, Salad, Manchow Soup, Manchurian',
#        'Chicken Quesadilla, Naan, Breakfast Buffet, Cheesecake, Cocktails, Lunch Buffet, Biryani',
#        'Biryani, Andhra Meal'], dtype=object)

# %%
df.dish_liked.describe()
# Out:
# count       23595
# unique       5271
# top       Biryani
# freq          182
# Name: dish_liked, dtype: object

# %%
from collections import Counter

# Combine all entries in 'dish_liked' into a single string
all_dishes = ' '.join(df['dish_liked'].dropna())
# Split the string into words
dish_list = all_dishes.split(', ')
# Count the frequency of each dish
dish_counts = Counter(dish_list)
# Get the most common dishes
common_dishes = dish_counts.most_common(10)
print(common_dishes)
# Out:
# [('Pasta', 2340), ('Cocktails', 1755), ('Pizza', 1672), ('Burgers', 1515), ('Mocktails', 1403), ('Sandwiches', 1084), ('Biryani', 1045), ('Nachos', 1005), ('Coffee', 1003), ('Fish', 935)]

# %%
dishes, frequencies = zip(*common_dishes)

# Plot the data
plt.figure(figsize=(10, 6))
plt.barh(dishes, frequencies)
plt.xlabel('Frequency')
plt.title('Top 10 Most Commonly Liked Dishes')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### i. cuisines

# %%
df['cuisines'].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ...,
#        'North Indian, Street Food, Biryani', 'Chinese, Mughlai',
#        'North Indian, Chinese, Arabian, Momos'], dtype=object)

# %%
df['cuisines'].nunique()
# Out:
# 2723

# %%
df['cuisines'].value_counts().head(10)
# Out:
# cuisines
# North Indian                           2907
# North Indian, Chinese                  2381
# South Indian                           1826
# Biryani                                 915
# Bakery, Desserts                        910
# Fast Food                               801
# Desserts                                760
# Cafe                                    755
# South Indian, North Indian, Chinese     726
# Bakery                                  651
# Name: count, dtype: int64

# %%
all_cuisines = ' '.join(df['cuisines'].dropna())
cuisine_list = all_cuisines.split(', ')
cuisine_counts = Counter(cuisine_list)
common_cuisines = cuisine_counts.most_common(10)


common_cuisines
# Out:
# [('Chinese', 5949),
#  ('North Indian', 5546),
#  ('Continental', 2581),
#  ('South Indian', 1950),
#  ('Italian', 1712),
#  ('Fast Food', 1641),
#  ('Biryani', 1436),
#  ('Chinese North Indian', 1364),
#  ('Desserts', 946),
#  ('Burger', 904)]

# %%
cuisines, frequencies = zip(*common_cuisines)

# %%
plt.figure(figsize=(10, 6))
plt.barh(cuisines, frequencies)
plt.xlabel('Frequency')
plt.title('Top 10 Most Commonly Liked Cuisines')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### j. couple_cost

# %%
df['couple_cost'].unique()
# Out:
# array([ 800.,  300.,  600.,  700.,  550.,  500.,  450.,  650.,  400.,
#         900.,  200.,  750.,  150.,  850.,  100., 1200.,  350.,  250.,
#         950., 1000., 1500., 1300.,  199.,   80., 1100.,  160., 1600.,
#         230.,  130.,   50.,  190., 1700.,   nan, 1400.,  180., 1350.,
#        2200., 2000., 1800., 1900.,  330., 2500., 2100., 3000., 2800.,
#        3400.,   40., 1250., 3500., 4000., 2400., 2600.,  120., 1450.,
#         469.,   70., 3200.,   60.,  560.,  240.,  360., 6000., 1050.,
#        2300., 4100., 5000., 3700., 1650., 2700., 4500.,  140.])

# %%
sns.histplot(x='couple_cost', data=df, kde=True)
plt.title('Distribution of Average Cost for Two People')
plt.xlabel('Cost')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(x='couple_cost', data=df, kde=True, bins=25)
plt.title('Distribution of Average Cost for Two People')
plt.xlabel('Cost')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['couple_cost'])
plt.title('Box Plot of Average Cost for Two People')
plt.xlabel('Cost')
plt.show()

# %%
sns.boxplot(x=df['couple_cost'])
sns.stripplot(x='couple_cost', data=df)
plt.title('Box Plot of Average Cost for Two People')
plt.xlabel('Cost')
plt.show()

# %%
q1_couples = df['couple_cost'].quantile(0.25)
q3_couples = df['couple_cost'].quantile(0.75)
iqr_couples = q3_couples - q1_couples
upper_bound_couples = q3_couples + 1.5 * iqr_couples
len(df[df['couple_cost'] >= upper_bound_couples])/len(df)*100
# Out:
# 9.18444457362088

# %% [markdown]
# We also have 9% of our data falling beyond the upper range which is considered a significant amount.

# %% [markdown]
# ### k. listed_type

# %%
df['listed_type'].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'], dtype=object)

# %%
plt.figure(figsize=(10, 8))
plt.pie(df['listed_type'].value_counts(), labels=df['listed_type'].value_counts().index, autopct='%1.1f%%')
plt.title("Types of Restaurants Listed")
plt.show()

# %%
sns.barplot(df['listed_type'].value_counts(), orient='h');
plt.title("Types of Restaurants Listed");
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ### l. city

# %%
df['city'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %%
df['city'].value_counts()
# Out:
# city
# BTM                      3266
# Koramangala 7th Block    2935
# Koramangala 5th Block    2832
# Koramangala 4th Block    2777
# Koramangala 6th Block    2622
# Jayanagar                2365
# JP Nagar                 2095
# Indiranagar              1856
# MG Road                  1806
# Church Street            1793
# Brigade Road             1768
# Lavelle Road             1741
# HSR                      1740
# Marathahalli             1657
# Residency Road           1619
# Whitefield               1617
# Bannerghatta Road        1616
# Brookefield              1517
# Old Airport Road         1422
# Kammanahalli             1326
# Kalyan Nagar             1305
# Basavanagudi             1266
# Sarjapur Road            1259
# Electronic City          1227
# Bellandur                1222
# Frazer Town              1185
# Malleshwaram             1095
# Rajajinagar              1078
# Banashankari              862
# New BEL Road              740
# Name: count, dtype: int64

# %%
sns.barplot(df['city'].value_counts().head(10), orient='h');
plt.title("Cities with Most Restaurants");
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Correlation between Numerical Values

# %%
sns.pairplot(df)

# %%
numerical_columns=df.select_dtypes(exclude=['O'])
numerical_columns
# Out:
#        rate  votes  couple_cost
# 0       4.1    775        800.0
# 1       4.1    787        800.0
# 2       3.8    918        800.0
# 3       3.7     88        300.0
# 4       3.8    166        600.0
# ...     ...    ...          ...
# 51712   3.6     27       1500.0
# 51713   NaN      0        600.0
# 51714   NaN      0       2000.0
# 51715   4.3    236       2500.0
# 51716   3.4     13       1500.0
#
# [51609 rows x 3 columns]

# %%
corr = numerical_columns.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Couple Cost per Restaurant

# %%
df.groupby('name')['couple_cost'].mean().sort_values(ascending=False).head(10)
# Out:
# name
# Le Cirque Signature - The Leela Palace    6000.0
# Royal Afghan - ITC Windsor                5000.0
# Malties - Radisson Blu                    4500.0
# La Brasserie - Le Meridien                4100.0
# Grill 99 - The Ritz-Carlton               4000.0
# Riwaz - The Ritz-Carlton                  4000.0
# Masala Klub - The Taj West End            4000.0
# Dum Pukht Jolly Nabobs - ITC Windsor      4000.0
# Alba - JW Marriott Bengaluru              4000.0
# Jamavar - The Leela Palace                4000.0
# Name: couple_cost, dtype: float64

# %%
plt.title('Fanciest Restaurant Couple Cost')
sns.barplot(df.groupby('name')['couple_cost'].mean().sort_values(ascending=False).head(10), orient='h')
plt.show()

# %%
df.groupby('name')['couple_cost'].mean().sort_values(ascending=True).head(10)
# Out:
# name
# Srinidhi Sagar Deluxe               40.000000
# Bread & Better                      50.000000
# Funky Food                          60.000000
# Nellore Dosa Camp                   70.000000
# Namaste                             70.000000
# Savera Cafe                         71.428571
# Dosa Cafe                           80.000000
# Dtink Lab                           80.000000
# Shree Ganesh Fruit Juice Centre     90.000000
# Sunmart Ice Cream Parlour          100.000000
# Name: couple_cost, dtype: float64

# %%
plt.title("Most Affordable for Couples")
sns.barplot(df.groupby('name')['couple_cost'].mean().sort_values(ascending=True).head(10), orient='h')
plt.show()

# %% [markdown]
# ### Top & Bottom Rated Restaurants

# %%
df.groupby('name')['rate'].mean().sort_values(ascending=False).head(10)
# Out:
# name
# SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Spa Cuisine    4.900000
# Byg Brewski Brewing Company                                                                                                                         4.900000
# Asia Kitchen By Mainland China                                                                                                                      4.900000
# Punjab Grill                                                                                                                                        4.871429
# Belgian Waffle Factory                                                                                                                              4.844828
# The Pizza Bakery                                                                                                                                    4.800000
# ...

# %%
df[df['name']=='SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Spa Cuisine']
# Out:
#                                                     name online_order  \
# 45812  SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...           No
#
#       book_table  rate  votes     location      rest_type  \
# 45812        Yes   4.9    246  Indiranagar  Casual Dining
#
#                                               dish_liked  \
# 45812  Biryani, Tomato Soup, Farm Pizza, Dumplings, L...
#
#                                  cuisines  couple_cost listed_type  \
# 45812  Healthy Food, Salad, Mediterranean       1000.0    Dine-out
#
#                    city subtype
# 45812  Old Airport Road     NaN

# %%
df.loc[45812, 'name'] = 'Santa Spa Cuisine'

# %%
#Top Rated Restaurants
df.groupby('name')['rate'].mean().sort_values(ascending=False).head(10)
# Out:
# name
# Santa Spa Cuisine                 4.900000
# Byg Brewski Brewing Company       4.900000
# Asia Kitchen By Mainland China    4.900000
# Punjab Grill                      4.871429
# Belgian Waffle Factory            4.844828
# The Pizza Bakery                  4.800000
# O.G. Variar & Sons                4.800000
# Flechazo                          4.800000
# AB's - Absolute Barbecues         4.789474
# Biergarten                        4.766667
# Name: rate, dtype: float64

# %%
#Least Favoured Restarants
df.groupby('name')['rate'].mean().sort_values(ascending=True).head(10)
# Out:
# name
# Alibi - Maya International Hotel    1.800000
# Fusion Lounge                       2.000000
# Decker's Lane                       2.100000
# Bageecha                            2.150000
# Mamma Mexicana                      2.200000
# Taste Of Kerala                     2.240000
# Bhagini                             2.283333
# Meghana Biryani                     2.300000
# Biryani Junction                    2.300000
# Vande Matharam                      2.300000
# Name: rate, dtype: float64

# %% [markdown]
# ### Most Online Orders per Restaurant

# %%
most_online = df[df['online_order']=='Yes'].groupby('name')['online_order'].count().sort_values(ascending=False).head(10)
most_online
# Out:
# name
# Onesta               85
# Empire Restaurant    69
# Kanti Sweets         68
# Polar Bear           65
# Cafe Coffee Day      64
# Sweet Truth          60
# Pizza Hut            59
# Smoor                59
# McDonald's           58
# Just Bake            58
# Name: online_order, dtype: int64

# %%
sns.barplot(most_online, orient='h')
plt.title("Top Restaurants in Online Orders")
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
least_online = df[df['online_order']=='Yes'].groupby('name')['online_order'].count().sort_values(ascending=True).head(10)
least_online
# Out:
# name
# Burger Man                                                                                                                                                                                                                                                                          1
# CHAATter Box                                                                                                                                                                                                                                                                        1
# Gongura Biriyani House                                                                                                                                                                                                                                                              1
# ...

# %%
df[df['name']=='Draggers CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ©']
# Out:
#                                                     name online_order  \
# 26189  Draggers CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...          Yes
#
#       book_table  rate  votes      location rest_type  \
# 26189         No   4.0    277  Kalyan Nagar      Cafe
#
#                                               dish_liked  \
# 26189  Club Sandwich, Pizza, Burgers, Basil Chicken, ...
#
#                               cuisines  couple_cost listed_type          city  \
# 26189  Cafe, Continental, North Indian        900.0    Dine-out  Kammanahalli
#
#       subtype
# 26189     NaN

# %%
df.loc[26189, 'name'] = 'Draggers Cafe'

# %%
df[df['name']=='Draggers Cafe']
# Out:
#                 name online_order book_table  rate  votes      location  \
# 26189  Draggers Cafe          Yes         No   4.0    277  Kalyan Nagar
#
#       rest_type                                         dish_liked  \
# 26189      Cafe  Club Sandwich, Pizza, Burgers, Basil Chicken, ...
#
#                               cuisines  couple_cost listed_type          city  \
# 26189  Cafe, Continental, North Indian        900.0    Dine-out  Kammanahalli
#
#       subtype
# 26189     NaN

# %% [markdown]
# ### Surveys per Restaurant

# %%
df.groupby('name')['votes'].sum().sort_values(ascending=False).head(20)
# Out:
# name
# Onesta                         347520
# Truffles                       301059
# Empire Restaurant              229808
# Hammered                       180602
# The Black Pearl                172122
# Meghana Foods                  129557
# Barbeque Nation                108425
# Smally's Resto Cafe            102877
# Byg Brewski Brewing Company     99531
# Gilly's Restobar                98808
# Arbor Brewing Company           92362
# House Of Commons                90573
# Chutney Chang                   89910
# AB's - Absolute Barbecues       86418
# Church Street Social            83179
# Fenny's Lounge And Kitchen      82834
# Prost Brew Pub                  78609
# Stoner                          75194
# Koramangala Social              75021
# Barleyz                         74448
# Name: votes, dtype: int64

# %% [markdown]
# We can see here that lots of big restaurants do have a big amount of surveys which proves that we were right not to drop the values above the upper bound of the ***votes*** columns.

# %%
df.groupby('name')['votes'].sum().sort_values(ascending=True).head(20)
# Out:
# name
# sCoolMeal                    0
# Multi Ruchish                0
# Multi Kitchen                0
# Mukesh Sweet Centre          0
# Mughal's                     0
# Mudaliar's Kitchen           0
# Mr.Khana Khazana             0
# Multi Snacky Hub             0
# Mr.Boiler                    0
# Mr. Paratha & Ms. Curry      0
# Chickpete Donne Biryani      0
# Mr. Chaiwala                 0
# Mr. Cane                     0
# Chikkanna Biryani Hotel      0
# Mr. Anbu's Ambur Biriyani    0
# Mr. Parathewala              0
# Mumbai Vada Pav              0
# Mumichi                      0
# Munch Box                    0
# Chef Snow                    0
# Name: votes, dtype: int64

# %%
df[df['votes']>4].groupby('name')['votes'].sum().sort_values(ascending=True).head(20)
# Out:
# name
# Senthur Cafe                   5
# Pink Pepper                    5
# The Sip Shop                   5
# Zaitoon Lassi Cafe             5
# Navami Kitchen                 5
# Sree Ganesha Fruits & Juice    5
# Star Ambur Dum Biryani         5
# Nawabs Empire                  5
# Nellore Dosa Camp              5
# Hotel Meed Cafe                5
# Hotel Narmada Andhra Style     5
# Hotel Nisarga                  5
# Karnataka Briyani point        5
# New Udupi Grand Hotel          5
# SLV Kabab Centre               5
# The Kimchi Chef                5
# Yi Moi Chinese Fast Food       5
# Subzero Korner                 5
# Santhrupthi                    5
# Bollywood Grill                5
# Name: votes, dtype: int64

# %%
df[df['votes']>40].groupby('name')['votes'].sum().sort_values(ascending=True).head(20)
# Out:
# name
# Sri Krishna Aramane                41
# Sadi's Biriyani                    41
# Shahi Kabab                        41
# Jay Bhavani                        41
# Ambur Biriyani                     41
# New Imperial Restaurant            41
# Shawarma King Restaurant           41
# Chawla's 2 Online.com              41
# AKS Family Dhaba And Restaurant    41
# Surya Refreshments                 41
# Latitude - Tulip Inn               42
# Mangalore Kitchen                  42
# Dreamland Food Corner              42
# The Table                          42
# Mad Over Fries                     43
# Hotel Manarama                     43
# Familiar Food Court                43
# Davanagere Butter Dosa Hotel       43
# Fresh Aahar                        43
# Food Republic Resto                43
# Name: votes, dtype: int64

# %% [markdown]
# It's obvious that most of the restaurants are need to promote their surveys more properly to their customers. They will then have better understanding on their customer's statisfaction. This should lead to improvement on the business over all.
#
# This also indicates that the dataset includes data about restaurant from very variant levels.

# %% [markdown]
# ### Couple Cost with or without booking

# %%
couple_booking = df.groupby('book_table')['couple_cost'].mean()

# %%
sns.barplot(df.groupby('book_table')['couple_cost'].mean())
plt.title("Average Couple Cost and Booking Relationship")
plt.show()

# %% [markdown]
# ### Couple Cost per Restaurant Types

# %%
df.groupby('listed_type')['couple_cost'].mean().sort_values(ascending=False)
# Out:
# listed_type
# Drinks & nightlife    1444.972325
# Pubs and bars         1327.405248
# Buffet                1306.559264
# Cafes                  627.803876
# Dine-out               591.706059
# Delivery               464.383751
# Desserts               392.270179
# Name: couple_cost, dtype: float64

# %%
sns.barplot(df.groupby('listed_type')['couple_cost'].mean().sort_values(ascending=False), orient='h')
plt.title("Average Couple Cost per Restaurant Type")
plt.show()

# %% [markdown]
# ### Rates per Restaurant Types

# %%
df.groupby('listed_type')['rate'].mean().sort_values(ascending=False)
# Out:
# listed_type
# Pubs and bars         4.021160
# Drinks & nightlife    4.014504
# Buffet                3.981712
# Cafes                 3.872477
# Desserts              3.777013
# Dine-out              3.680643
# Delivery              3.653024
# Name: rate, dtype: float64

# %%
sns.barplot(df.groupby('listed_type')['rate'].mean().sort_values(ascending=False), orient='h')
plt.title("Average Rate per Restaurant Type")
plt.xlim(3,4.1)
plt.show()

# %% [markdown]
# ### Rates per Restaurant Subtypes

# %%
df.groupby('subtype')['rate'].mean().sort_values(ascending=False)
# Out:
# subtype
# Irani Cafee       4.406667
# Microbrewery      4.321290
# Pub               4.253448
# Lounge            4.235185
# Casual Dining     4.128838
# Cafe              4.115515
# Bar               4.078952
# Dessert Parlor    3.870258
# Bakery            3.854297
# Beverage Shop     3.757432
# Meat Shop         3.700000
# Quick Bites       3.616472
# Sweet Shop        3.562105
# Delivery          3.513344
# Mess              3.425000
# Food Court        3.373913
# Kiosk             3.100000
# Name: rate, dtype: float64

# %%
sns.barplot(df.groupby('subtype')['rate'].mean().sort_values(ascending=False), orient='h')
plt.title("Average Rate per Restaurant Subtype")
plt.show()

# %% [markdown]
# ### Surveys per Restaurant Types

# %%
df.groupby('listed_type')['votes'].sum().sort_values(ascending=False)
# Out:
# listed_type
# Delivery              5271351
# Dine-out              5149233
# Drinks & nightlife    1250632
# Buffet                 885181
# Cafes                  826857
# Pubs and bars          695423
# Desserts               541294
# Name: votes, dtype: int64

# %%
sns.barplot(df.groupby('listed_type')['votes'].sum().sort_values(ascending=False), orient='h')
plt.title("Total Surveys per Restaurant Type")
plt.show()

# %% [markdown]
# ## Affordable vs Expensive Restaurants for Couples

# %%
df.groupby('name')['couple_cost'].mean().sort_values(ascending=True).head(10)
# Out:
# name
# Srinidhi Sagar Deluxe               40.000000
# Bread & Better                      50.000000
# Funky Food                          60.000000
# Nellore Dosa Camp                   70.000000
# Namaste                             70.000000
# Savera Cafe                         71.428571
# Dosa Cafe                           80.000000
# Dtink Lab                           80.000000
# Shree Ganesh Fruit Juice Centre     90.000000
# Sunmart Ice Cream Parlour          100.000000
# Name: couple_cost, dtype: float64

# %%
df.groupby('name')['couple_cost'].mean().sort_values(ascending=False).head(10)
# Out:
# name
# Le Cirque Signature - The Leela Palace    6000.0
# Royal Afghan - ITC Windsor                5000.0
# Malties - Radisson Blu                    4500.0
# La Brasserie - Le Meridien                4100.0
# Grill 99 - The Ritz-Carlton               4000.0
# Riwaz - The Ritz-Carlton                  4000.0
# Masala Klub - The Taj West End            4000.0
# Dum Pukht Jolly Nabobs - ITC Windsor      4000.0
# Alba - JW Marriott Bengaluru              4000.0
# Jamavar - The Leela Palace                4000.0
# Name: couple_cost, dtype: float64

# %%
plt.title("Luxurious Cuisines for Couples")
sns.barplot(df.groupby('name')['couple_cost'].mean().sort_values(ascending=False).head(10), orient='h')
plt.show()

# %% [markdown]
# ### Average Online Couple Cost

# %%
df[df['online_order']=='Yes'].groupby('online_order')['couple_cost'].mean()
# Out:
# online_order
# Yes    525.007279
# Name: couple_cost, dtype: float64

# %% [markdown]
# ### Average Online Couple Cost per Restaurant Type

# %%
df[df['online_order']=='Yes'].groupby(['listed_type'])['couple_cost'].mean()
# Out:
# listed_type
# Buffet                1169.318182
# Cafes                  626.336303
# Delivery               483.344111
# Desserts               414.463311
# Dine-out               561.814869
# Drinks & nightlife    1391.737288
# Pubs and bars         1267.989418
# Name: couple_cost, dtype: float64

# %%
sns.barplot(df[df['online_order']=='Yes'].groupby(['listed_type'])['couple_cost'].mean().sort_values(ascending=False), orient='h')
plt.title("Average Online Couple Cost per Restaurant Type")
plt.show()

# %% [markdown]
# ### Top Rated Cuisines

# %%
df.groupby('cuisines')['rate'].mean().sort_values(ascending=False).head(10)
# Out:
# cuisines
# Continental, North Indian, Italian, South Indian, Finger Food            4.900000
# Healthy Food, Salad, Mediterranean                                       4.900000
# Asian, Chinese, Thai, Momos                                              4.900000
# Continental, North Indian, Chinese, European, BBQ, Finger Food, Asian    4.800000
# Asian, Mediterranean, North Indian, BBQ                                  4.800000
# North Indian, European, Mediterranean, BBQ                               4.800000
# European, Mediterranean, North Indian, BBQ                               4.789474
# American, Tex-Mex, Burger, BBQ, Mexican                                  4.750000
# Asian, Burmese                                                           4.700000
# BBQ, North Indian, Continental, Chinese                                  4.700000
# Name: rate, dtype: float64

# %% [markdown]
# ### Most Booked Cuisines

# %%
most_booked_cuisines = df[df['book_table']=='Yes'].groupby('cuisines')['book_table'].count().sort_values(ascending=False).head(10)
most_booked_cuisines
# Out:
# cuisines
# North Indian                 295
# North Indian, Chinese        122
# Pizza, Cafe, Italian          85
# North Indian, Mughlai         85
# Finger Food                   74
# Chinese                       54
# Continental, North Indian     48
# Chinese, Momos                46
# Modern Indian                 45
# Continental                   43
# Name: book_table, dtype: int64

# %%
sns.barplot(most_booked_cuisines, orient='h')
plt.title("Most Booked Cuisines")
plt.show()

# %% [markdown]
# ### Online Orders Rates

# %%
df[df['online_order']=='Yes'].groupby('online_order')['rate'].mean()
# Out:
# online_order
# Yes    3.722287
# Name: rate, dtype: float64

# %% [markdown]
# ## Handling Missing Values

# %%
df.isnull().mean()*100
# Out:
# name             0.000000
# online_order     0.000000
# book_table       0.000000
# rate            19.413281
# votes            0.000000
# location         0.040691
# rest_type        0.439846
# dish_liked      54.281230
# cuisines         0.087194
# couple_cost      0.666550
# listed_type      0.000000
# city             0.000000
# subtype         85.072371
# dtype: float64

# %% [markdown]
# ### a. Categorical

# %%
df = df.drop(['dish_liked', 'name', 'subtype'], axis=1)
df.head()
# Out:
#   online_order book_table  rate  votes      location      rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari  Casual Dining
# 1          Yes         No   4.1    787  Banashankari  Casual Dining
# 2          Yes         No   3.8    918  Banashankari           Cafe
# 3           No         No   3.7     88  Banashankari    Quick Bites
# 4           No         No   3.8    166  Basavanagudi  Casual Dining
#
#                          cuisines  couple_cost listed_type          city
# 0  North Indian, Mughlai, Chinese        800.0      Buffet  Banashankari
# 1     Chinese, North Indian, Thai        800.0      Buffet  Banashankari
# 2          Cafe, Mexican, Italian        800.0      Buffet  Banashankari
# 3      South Indian, North Indian        300.0      Buffet  Banashankari
# 4        North Indian, Rajasthani        600.0      Buffet  Banashankari

# %%
df.shape
# Out:
# (51609, 10)

# %% [markdown]
# #### Cuisines

# %%
# since the amount of missing values in this feature is very small,
# we will confidently drop them

df = df.dropna(subset=['cuisines'])

# %%
df.isnull().mean()*100
# Out:
# online_order     0.000000
# book_table       0.000000
# rate            19.364285
# votes            0.000000
# location         0.000000
# rest_type        0.399504
# cuisines         0.000000
# couple_cost      0.616709
# listed_type      0.000000
# city             0.000000
# dtype: float64

# %%
df.shape
# Out:
# (51564, 10)

# %% [markdown]
# ### b. Numerical

# %% [markdown]
# Let's have a look again on the ***rates*** column distribution.

# %%
sns.histplot(x='rate', data=df, kde=True);

# %%
sns.boxplot(x='rate', data=df);
sns.stripplot(x='rate', data=df, color='gray');

# %%
q1_rate = df['rate'].quantile(0.25)
df[df['rate']<q1_rate]
# Out:
#       online_order book_table  rate  votes      location      rest_type  \
# 19             Yes         No   3.1     13  Banashankari           Cafe
# 20             Yes         No   3.0     62  Banashankari           Cafe
# 25              No         No   3.2     11  Banashankari           Cafe
# 27              No         No   3.3      4  Banashankari           Cafe
# 28              No         No   3.3     23  Banashankari           Cafe
# ...            ...        ...   ...    ...           ...            ...
# 51637           No         No   3.3      6   Brookefield  Beverage Shop
# 51641           No         No   3.2      4   Brookefield    Quick Bites
# 51677           No         No   2.5     81    Whitefield  Casual Dining
# 51708           No         No   2.8    161    Whitefield  Casual Dining
# 51711           No         No   2.5     81    Whitefield  Casual Dining
#
#                                           cuisines  couple_cost  \
# ...

# %%
len(df[df['rate']<q1_rate])/len(df)*100
# Out:
# 17.46567372585525

# %% [markdown]
# Since we cannot drop the significant amount of outliers here, we will fill out the missing ***rate*** values using the **Mean** per each restaurant ***listed_type***.

# %%
df.groupby('listed_type')['rate'].mean()
# Out:
# listed_type
# Buffet                3.981712
# Cafes                 3.872477
# Delivery              3.653078
# Desserts              3.777151
# Dine-out              3.680679
# Drinks & nightlife    4.014504
# Pubs and bars         4.021160
# Name: rate, dtype: float64

# %%
df['rate'] = df.groupby('listed_type')['rate'].transform(lambda x: x.fillna(x.mean()))

# %%
#checking on missing values again
df.isnull().mean()*100
# Out:
# online_order    0.000000
# book_table      0.000000
# rate            0.000000
# votes           0.000000
# location        0.000000
# rest_type       0.399504
# cuisines        0.000000
# couple_cost     0.616709
# listed_type     0.000000
# city            0.000000
# dtype: float64

# %% [markdown]
# Since the rest of missing values are not significant amounts we can just drop them

# %%
df.dropna(axis=0).shape
# Out:
# (51042, 10)

# %%
df.dropna(axis=0, inplace=True)

# %%
#final check on nulls
df.isnull().mean()*100
# Out:
# online_order    0.0
# book_table      0.0
# rate            0.0
# votes           0.0
# location        0.0
# rest_type       0.0
# cuisines        0.0
# couple_cost     0.0
# listed_type     0.0
# city            0.0
# dtype: float64

# %%
df.shape
# Out:
# (51042, 10)

# %% [markdown]
# # Machine Learning

# %%
import time
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, roc_auc_score, roc_curve, auc
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.svm import LinearSVC

# %%
#let's have a final look on our data
df.head()
# Out:
#   online_order book_table  rate  votes      location      rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari  Casual Dining
# 1          Yes         No   4.1    787  Banashankari  Casual Dining
# 2          Yes         No   3.8    918  Banashankari           Cafe
# 3           No         No   3.7     88  Banashankari    Quick Bites
# 4           No         No   3.8    166  Basavanagudi  Casual Dining
#
#                          cuisines  couple_cost listed_type          city
# 0  North Indian, Mughlai, Chinese        800.0      Buffet  Banashankari
# 1     Chinese, North Indian, Thai        800.0      Buffet  Banashankari
# 2          Cafe, Mexican, Italian        800.0      Buffet  Banashankari
# 3      South Indian, North Indian        300.0      Buffet  Banashankari
# 4        North Indian, Rajasthani        600.0      Buffet  Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51042 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   online_order  51042 non-null  object
#  1   book_table    51042 non-null  object
#  2   rate          51042 non-null  float64
#  3   votes         51042 non-null  int64
#  4   location      51042 non-null  object
#  5   rest_type     51042 non-null  object
#  6   cuisines      51042 non-null  object
#  7   couple_cost   51042 non-null  float64
#  8   listed_type   51042 non-null  object
#  9   city          51042 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 4.3+ MB

# %% [markdown]
# ## Encoding Categorical Data

# %%
df[['online_order', 'book_table', 'location', 'rest_type','cuisines','listed_type', 'city']].nunique()
# Out:
# online_order       2
# book_table         2
# location          93
# rest_type         23
# cuisines        2704
# listed_type        7
# city              30
# dtype: int64

# %% [markdown]
# ### Ordinal Data

# %% [markdown]
# Our ordinal features are ***online_order*** & ***book_table***.

# %%
label_encoder = LabelEncoder()
df['online_encoded'] = label_encoder.fit_transform(df['online_order'])
df['book_encoded'] = label_encoder.fit_transform(df['book_table'])

#adding inverses to check on the correct ordinality
df['online_encoded_inverse'] = label_encoder.inverse_transform(df['online_encoded'])
df['book_encoded_inverse'] = label_encoder.inverse_transform(df['book_encoded'])

# %%
df.head()
# Out:
#   online_order book_table  rate  votes      location      rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari  Casual Dining
# 1          Yes         No   4.1    787  Banashankari  Casual Dining
# 2          Yes         No   3.8    918  Banashankari           Cafe
# 3           No         No   3.7     88  Banashankari    Quick Bites
# 4           No         No   3.8    166  Basavanagudi  Casual Dining
#
#                          cuisines  couple_cost listed_type          city  \
# 0  North Indian, Mughlai, Chinese        800.0      Buffet  Banashankari
# 1     Chinese, North Indian, Thai        800.0      Buffet  Banashankari
# 2          Cafe, Mexican, Italian        800.0      Buffet  Banashankari
# 3      South Indian, North Indian        300.0      Buffet  Banashankari
# 4        North Indian, Rajasthani        600.0      Buffet  Banashankari
#
#    online_encoded  book_encoded online_encoded_inverse book_encoded_inverse
# ...

# %% [markdown]
# Great! Now we can drop the original columns and the inversed

# %%
df.drop(['online_order', 'book_table', 'online_encoded_inverse', 'book_encoded_inverse'], axis=1)
# Out:
#           rate  votes                    location      rest_type  \
# 0      4.10000    775                Banashankari  Casual Dining
# 1      4.10000    787                Banashankari  Casual Dining
# 2      3.80000    918                Banashankari           Cafe
# 3      3.70000     88                Banashankari    Quick Bites
# 4      3.80000    166                Basavanagudi  Casual Dining
# ...        ...    ...                         ...            ...
# 51712  3.60000     27                  Whitefield            Bar
# 51713  4.02116      0                  Whitefield            Bar
# 51714  4.02116      0                  Whitefield            Bar
# 51715  4.30000    236  ITPL Main Road, Whitefield            Bar
# 51716  3.40000     13  ITPL Main Road, Whitefield            Bar
#
#                                      cuisines  couple_cost    listed_type  \
# 0              North Indian, Mughlai, Chinese        800.0         Buffet
# ...

# %%
df = df.drop(['online_order', 'book_table', 'online_encoded_inverse', 'book_encoded_inverse'], axis=1)

# %% [markdown]
# ### Nominal Data

# %% [markdown]
# #### Frequency Encoding

# %%
nominal_columns = ['location', 'rest_type','listed_type', 'city']

# %%
for col in nominal_columns:
    df[col+'_encoded'] = df[col].map(df[col].value_counts()) / len(df)

df.head()
# Out:
#    rate  votes      location      rest_type                        cuisines  \
# 0   4.1    775  Banashankari  Casual Dining  North Indian, Mughlai, Chinese
# 1   4.1    787  Banashankari  Casual Dining     Chinese, North Indian, Thai
# 2   3.8    918  Banashankari           Cafe          Cafe, Mexican, Italian
# 3   3.7     88  Banashankari    Quick Bites      South Indian, North Indian
# 4   3.8    166  Basavanagudi  Casual Dining        North Indian, Rajasthani
#
#    couple_cost listed_type          city  online_encoded  book_encoded  \
# 0        800.0      Buffet  Banashankari               1             1
# 1        800.0      Buffet  Banashankari               1             0
# 2        800.0      Buffet  Banashankari               1             0
# 3        300.0      Buffet  Banashankari               0             0
# 4        600.0      Buffet  Banashankari               0             0
#
#    location_encoded  rest_type_encoded  listed_type_encoded  city_encoded
# ...

# %%
#let's drop the original cols
df = df.drop(nominal_columns, axis=1)
df
# Out:
#           rate  votes                                cuisines  couple_cost  \
# 0      4.10000    775          North Indian, Mughlai, Chinese        800.0
# 1      4.10000    787             Chinese, North Indian, Thai        800.0
# 2      3.80000    918                  Cafe, Mexican, Italian        800.0
# 3      3.70000     88              South Indian, North Indian        300.0
# 4      3.80000    166                North Indian, Rajasthani        600.0
# ...        ...    ...                                     ...          ...
# 51712  3.60000     27                             Continental       1500.0
# 51713  4.02116      0                             Finger Food        600.0
# 51714  4.02116      0                             Finger Food       2000.0
# 51715  4.30000    236                             Finger Food       2500.0
# 51716  3.40000     13  Finger Food, North Indian, Continental       1500.0
#
# ...

# %% [markdown]
# #### One-Hot Encoding

# %% [markdown]
# It seems like ***cuisines*** will need special effort in **preprocessing** then **encoding**

# %%
df['cuisines'] = df['cuisines'].str.lower().str.strip()
df['cuisines'] = df['cuisines'].str.split(', ')
df['cuisines']
# Out:
# 0                [north indian, mughlai, chinese]
# 1                   [chinese, north indian, thai]
# 2                        [cafe, mexican, italian]
# 3                    [south indian, north indian]
# 4                      [north indian, rajasthani]
#                            ...
# 51712                               [continental]
# 51713                               [finger food]
# 51714                               [finger food]
# 51715                               [finger food]
# 51716    [finger food, north indian, continental]
# Name: cuisines, Length: 51042, dtype: object

# %%
# Get top 20 cuisines
N = 5
cuisine_counts = Counter([cuisine for sublist in df['cuisines'] for cuisine in sublist])
top_cuisines = {c for c, _ in cuisine_counts.most_common(N)}

#having a look
top_cuisines
# Out:
# {'biryani', 'chinese', 'fast food', 'north indian', 'south indian'}

# %%
print("Top", N, "cuisines:\n")
for cuisine, count in cuisine_counts.most_common(N):
    print(f"{cuisine}: {count}")
# Out:
# Top 5 cuisines:
#
# north indian: 20800
# chinese: 15338
# south indian: 8561
# fast food: 8027
# biryani: 6411

# %%
# Visualization of top N cuisines
plt.figure(figsize=(8, 5))
cuisine_names, cuisine_values = zip(*cuisine_counts.most_common(N))
plt.barh(cuisine_names, cuisine_values)
plt.xlabel("Cuisine")
plt.ylabel("Count")
plt.title(f"Top {N} Cuisines")
plt.gca().invert_yaxis()  # Invert y-axis for descending order
plt.show()

# %%
def filter_top_cuisines(cuisine_list):
    if not isinstance(cuisine_list, list):
        return ['other']
    return [c if c in top_cuisines else 'other' for c in cuisine_list]

df['cuisines'] = df['cuisines'].apply(filter_top_cuisines)
df['cuisines']
# Out:
# 0        [north indian, other, chinese]
# 1        [chinese, north indian, other]
# 2                 [other, other, other]
# 3          [south indian, north indian]
# 4                 [north indian, other]
#                       ...
# 51712                           [other]
# 51713                           [other]
# 51714                           [other]
# 51715                           [other]
# 51716      [other, north indian, other]
# Name: cuisines, Length: 51042, dtype: object

# %%
# Merge all cuisine labels into a single column
df['cuisines'] = df['cuisines'].apply(lambda x: ', '.join(set(x)))  # Remove duplicates & join into string
df['cuisines']
# Out:
# 0        other, north indian, chinese
# 1        chinese, other, north indian
# 2                               other
# 3          south indian, north indian
# 4                 other, north indian
#                      ...
# 51712                           other
# 51713                           other
# 51714                           other
# 51715                           other
# 51716             other, north indian
# Name: cuisines, Length: 51042, dtype: object

# %%
#getting the cuisines back into lists for the next steps
df['cuisines'] = df['cuisines'].str.split(', ')
df['cuisines']
# Out:
# 0        [other, north indian, chinese]
# 1        [chinese, other, north indian]
# 2                               [other]
# 3          [south indian, north indian]
# 4                 [other, north indian]
#                       ...
# 51712                           [other]
# 51713                           [other]
# 51714                           [other]
# 51715                           [other]
# 51716             [other, north indian]
# Name: cuisines, Length: 51042, dtype: object

# %%
cuisines_expanded = df.explode('cuisines')
cuisines_expanded
# Out:
#           rate  votes      cuisines  couple_cost  online_encoded  \
# 0      4.10000    775         other        800.0               1
# 0      4.10000    775  north indian        800.0               1
# 0      4.10000    775       chinese        800.0               1
# 1      4.10000    787       chinese        800.0               1
# 1      4.10000    787         other        800.0               1
# ...        ...    ...           ...          ...             ...
# 51713  4.02116      0         other        600.0               0
# 51714  4.02116      0         other       2000.0               0
# 51715  4.30000    236         other       2500.0               0
# 51716  3.40000     13         other       1500.0               0
# 51716  3.40000     13  north indian       1500.0               0
#
#        book_encoded  location_encoded  rest_type_encoded  listed_type_encoded  \
# 0                 1          0.017672           0.233239             0.017025
# ...

# %%
cuisines_expanded.head(10)
# Out:
#    rate  votes      cuisines  couple_cost  online_encoded  book_encoded  \
# 0   4.1    775         other        800.0               1             1
# 0   4.1    775  north indian        800.0               1             1
# 0   4.1    775       chinese        800.0               1             1
# 1   4.1    787       chinese        800.0               1             0
# 1   4.1    787         other        800.0               1             0
# 1   4.1    787  north indian        800.0               1             0
# 2   3.8    918         other        800.0               1             0
# 3   3.7     88  south indian        300.0               0             0
# 3   3.7     88  north indian        300.0               0             0
# 4   3.8    166         other        600.0               0             0
#
#    location_encoded  rest_type_encoded  listed_type_encoded  city_encoded
# 0          0.017672           0.233239             0.017025      0.016829
# ...

# %%
one_hot_encoded = pd.get_dummies(cuisines_expanded['cuisines'])
one_hot_encoded
# Out:
#        biryani  chinese  fast food  north indian  other  south indian
# 0        False    False      False         False   True         False
# 0        False    False      False          True  False         False
# 0        False     True      False         False  False         False
# 1        False     True      False         False  False         False
# 1        False    False      False         False   True         False
# ...        ...      ...        ...           ...    ...           ...
# 51713    False    False      False         False   True         False
# 51714    False    False      False         False   True         False
# 51715    False    False      False         False   True         False
# 51716    False    False      False         False   True         False
# 51716    False    False      False          True  False         False
#
# [94642 rows x 6 columns]

# %%
one_hot_encoded.head(10)
# Out:
#    biryani  chinese  fast food  north indian  other  south indian
# 0    False    False      False         False   True         False
# 0    False    False      False          True  False         False
# 0    False     True      False         False  False         False
# 1    False     True      False         False  False         False
# 1    False    False      False         False   True         False
# 1    False    False      False          True  False         False
# 2    False    False      False         False   True         False
# 3    False    False      False         False  False          True
# 3    False    False      False          True  False         False
# 4    False    False      False         False   True         False

# %%
df_final = cuisines_expanded.join(one_hot_encoded).groupby(level=0).max()
df_final
# Out:
#           rate  votes      cuisines  couple_cost  online_encoded  \
# 0      4.10000    775         other        800.0               1
# 1      4.10000    787         other        800.0               1
# 2      3.80000    918         other        800.0               1
# 3      3.70000     88  south indian        300.0               0
# 4      3.80000    166         other        600.0               0
# ...        ...    ...           ...          ...             ...
# 51712  3.60000     27         other       1500.0               0
# 51713  4.02116      0         other        600.0               0
# 51714  4.02116      0         other       2000.0               0
# 51715  4.30000    236         other       2500.0               0
# 51716  3.40000     13         other       1500.0               0
#
#        book_encoded  location_encoded  rest_type_encoded  listed_type_encoded  \
# 0                 1          0.017672           0.233239             0.017025
# ...

# %% [markdown]
# We will now need to switch the *True* & *False* values into Ones and Zeros.

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51042 entries, 0 to 51716
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rate                 51042 non-null  float64
#  1   votes                51042 non-null  int64
#  2   cuisines             51042 non-null  object
#  3   couple_cost          51042 non-null  float64
#  4   online_encoded       51042 non-null  int32
#  5   book_encoded         51042 non-null  int32
#  6   location_encoded     51042 non-null  float64
#  7   rest_type_encoded    51042 non-null  float64
#  8   listed_type_encoded  51042 non-null  float64
#  9   city_encoded         51042 non-null  float64
#  10  biryani              51042 non-null  bool
#  11  chinese              51042 non-null  bool
#  12  fast food            51042 non-null  bool
#  13  north indian         51042 non-null  bool
#  14  other                51042 non-null  bool
# ...

# %%
bool_cols = df_final.select_dtypes(include='bool').columns
bool_cols
# Out:
# Index(['biryani', 'chinese', 'fast food', 'north indian', 'other',
#        'south indian'],
#       dtype='object')

# %%
df_final[bool_cols] = df_final[bool_cols].astype(int)
df_final.head()
# Out:
#    rate  votes      cuisines  couple_cost  online_encoded  book_encoded  \
# 0   4.1    775         other        800.0               1             1
# 1   4.1    787         other        800.0               1             0
# 2   3.8    918         other        800.0               1             0
# 3   3.7     88  south indian        300.0               0             0
# 4   3.8    166         other        600.0               0             0
#
#    location_encoded  rest_type_encoded  listed_type_encoded  city_encoded  \
# 0          0.017672           0.233239             0.017025      0.016829
# 1          0.017672           0.233239             0.017025      0.016829
# 2          0.017672           0.084499             0.017025      0.016829
# 3          0.017672           0.380060             0.017025      0.016829
# 4          0.013401           0.233239             0.017025      0.016829
#
#    biryani  chinese  fast food  north indian  other  south indian
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51042 entries, 0 to 51716
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rate                 51042 non-null  float64
#  1   votes                51042 non-null  int64
#  2   cuisines             51042 non-null  object
#  3   couple_cost          51042 non-null  float64
#  4   online_encoded       51042 non-null  int32
#  5   book_encoded         51042 non-null  int32
#  6   location_encoded     51042 non-null  float64
#  7   rest_type_encoded    51042 non-null  float64
#  8   listed_type_encoded  51042 non-null  float64
#  9   city_encoded         51042 non-null  float64
#  10  biryani              51042 non-null  int32
#  11  chinese              51042 non-null  int32
#  12  fast food            51042 non-null  int32
#  13  north indian         51042 non-null  int32
#  14  other                51042 non-null  int32
# ...

# %% [markdown]
# ## Preparing the Target Value

# %% [markdown]
# Since our goal is to predict whether or not a restaurant will be successfull, we will create a new threshold column to our target feature, ***Rate***.
# We will assign a variable to this threshold so that we can change it, if needed.

# %%
threshold = 3.5
df_final['target'] = (df_final['rate'] >= threshold).astype(int)  # Convert rate to 0 or 1 based on the threshold
df_final
# Out:
#           rate  votes      cuisines  couple_cost  online_encoded  \
# 0      4.10000    775         other        800.0               1
# 1      4.10000    787         other        800.0               1
# 2      3.80000    918         other        800.0               1
# 3      3.70000     88  south indian        300.0               0
# 4      3.80000    166         other        600.0               0
# ...        ...    ...           ...          ...             ...
# 51712  3.60000     27         other       1500.0               0
# 51713  4.02116      0         other        600.0               0
# 51714  4.02116      0         other       2000.0               0
# 51715  4.30000    236         other       2500.0               0
# 51716  3.40000     13         other       1500.0               0
#
#        book_encoded  location_encoded  rest_type_encoded  listed_type_encoded  \
# 0                 1          0.017672           0.233239             0.017025
# ...

# %%
# Doughnut Chart Visualization
above_threshold = df_final['target'].sum()
below_threshold = len(df) - above_threshold

# Data for the chart
data = [above_threshold, below_threshold]
labels = ['Above Threshold', 'Below Threshold']
colors = sns.color_palette("pastel")[0:2]

plt.figure(figsize=(8, 8))
plt.pie(data, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, pctdistance=0.85, wedgeprops={'width': 0.3})

# Draw center circle for doughnut shape
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Distribution of Restaurants Above and Below Threshold')
plt.show()

# %% [markdown]
# ## Splitting the data

# %%
X=df_final.drop(['cuisines','rate','target'], axis=1)
y=df_final['target']

# %%
X
# Out:
#        votes  couple_cost  online_encoded  book_encoded  location_encoded  \
# 0        775        800.0               1             1          0.017672
# 1        787        800.0               1             0          0.017672
# 2        918        800.0               1             0          0.017672
# 3         88        300.0               0             0          0.017672
# 4        166        600.0               0             0          0.013401
# ...      ...          ...             ...           ...               ...
# 51712     27       1500.0               0             0          0.041241
# 51713      0        600.0               0             0          0.041241
# 51714      0       2000.0               0             0          0.041241
# 51715    236       2500.0               0             1          0.002214
# 51716     13       1500.0               0             0          0.002214
#
#        rest_type_encoded  listed_type_encoded  city_encoded  biryani  chinese  \
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 51712    1
# 51713    1
# 51714    1
# 51715    1
# 51716    0
# Name: target, Length: 51042, dtype: int32

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Tree Models

# %% [markdown]
# Since Tree Models are not sensitive to scaling, we will implement, train and evaluate them without scaling the data.
# We will be using two classifiers:
#
# * Decision Tree
# * Random Forest

# %% [markdown]
# ### Decision Tree

# %%
def visualize_cv_results(grid_search):
    results = pd.DataFrame(grid_search.cv_results_)
    # Extract parameter columns dynamically
    param_columns = [col for col in results.columns if col.startswith('param_')]
    # Add mean test score 
    param_columns.extend(['mean_test_score'])
    # Create a table with dynamic columns and accuracy score
    table = results[param_columns]
    return table.sort_values(by='mean_test_score', ascending=False).head(1)

# %%
def plot_feature_importances(model, features):
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1]

    plt.figure(figsize=(12, 8))
    sns.barplot(x=importances[indices], y=[features[i] for i in indices])
    plt.title('Feature Importances')
    plt.xlabel('Importance')
    plt.ylabel('Features')
    plt.show()

# %%
# Decision Tree with GridSearchCV
dec_tree = DecisionTreeClassifier()
param_grid = {'criterion': ['gini', 'entropy'], 
              'max_depth': [3, 5, 7, 10, 12],
              'min_samples_split': [2, 5, 10]
           }
grid_dec_tree = GridSearchCV(dec_tree, param_grid, cv=5)
start_time = time.time()
grid_dec_tree.fit(X_train, y_train)
end_time = time.time()
dt_elapsed_time = end_time - start_time

# %%
dt_elapsed_time
# Out:
# 6.569109916687012

# %%
print("Top Scoring Decision Tree Hyperparameters:\n")
visualize_cv_results(grid_dec_tree)
# Out:
# Top Scoring Decision Tree Hyperparameters:
#    param_criterion  param_max_depth  param_min_samples_split  mean_test_score
# 12            gini               12                        2         0.876823

# %%
# Evaluate on training data
dt_train_pred = grid_dec_tree.predict(X_train)
dt_train_pred_proba = grid_dec_tree.predict_proba(X_train)[:, 1]

dt_train_accuracy = accuracy_score(y_train, dt_train_pred)
dt_train_f1 = f1_score(y_train, dt_train_pred)
dt_train_auc = roc_auc_score(y_train, dt_train_pred_proba)

print("Decision Tree - Training Evaluation:\n\n")
print(f'Accuracy: {dt_train_accuracy}')
print(f'F1 Score: {dt_train_f1}')
print(f'ROC-AUC Score: {dt_train_auc}')
# Out:
# Decision Tree - Training Evaluation:
#
#
# Accuracy: 0.8993814548406057
# F1 Score: 0.9376160480330401
# ROC-AUC Score: 0.9479413313396338

# %%
# Evaluate on test data
dt_test_pred = grid_dec_tree.predict(X_test)
dt_test_pred_proba = grid_dec_tree.predict_proba(X_test)[:, 1]

dt_test_accuracy = accuracy_score(y_test, dt_test_pred)
dt_test_f1 = f1_score(y_test, dt_test_pred)
dt_test_auc = roc_auc_score(y_test, dt_test_pred_proba)

print("Decision Tree - Testing Evaluation:\n\n")
print(f'Accuracy: {dt_test_accuracy}')
print(f'F1 Score: {dt_test_f1}')
print(f'ROC-AUC Score: {dt_test_auc}')
# Out:
# Decision Tree - Testing Evaluation:
#
#
# Accuracy: 0.8828446418076145
# F1 Score: 0.9274506632157877
# ROC-AUC Score: 0.9187103881474465

# %%
# To retest our function
best_dt_params = grid_dec_tree.best_params_
print("Best Hyperparameters:", best_dt_params)
print('\n\n')
# Access the best estimator
best_dt_model = grid_dec_tree.best_estimator_
best_dt_model
# Out:
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 12, 'min_samples_split': 2}
# DecisionTreeClassifier(max_depth=12)

# %%
plot_feature_importances(best_dt_model, X.columns)

# %% [markdown]
# ### Random Forest

# %%
# Random Forest with GridSearchCV
rand_forest = RandomForestClassifier()
param_grid = {
    'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 7, 10],
    'min_samples_split': [2, 5, 10]
}   #reduced the hyperparameter grids just for comptational resources
grid_rand_forest = GridSearchCV(rand_forest, param_grid, cv=5)
start_time = time.time()
grid_rand_forest.fit(X_train, y_train)
end_time = time.time()
rf_elapsed_time = end_time - start_time

# %%
rf_elapsed_time
# Out:
# 343.41173934936523

# %%
print("Top Scoring Random Forest Hyperparameters:\n")
visualize_cv_results(grid_rand_forest)
# Out:
# Top Scoring Random Forest Hyperparameters:
#    param_criterion  param_max_depth  param_min_samples_split  \
# 28            gini               10                        2
#
#     param_n_estimators  mean_test_score
# 28                 100         0.865963

# %%
# Evaluate on training data
rf_train_pred = grid_rand_forest.predict(X_train)
rf_train_pred_proba = grid_rand_forest.predict_proba(X_train)[:, 1]

rf_train_accuracy = accuracy_score(y_train, rf_train_pred)
rf_train_f1 = f1_score(y_train, rf_train_pred)
rf_train_auc = roc_auc_score(y_train, rf_train_pred_proba)

print("Random Forest - Training Evaluation:\n\n")
print(f'Accuracy: {rf_train_accuracy}')
print(f'F1 Score: {rf_train_f1}')
print(f'ROC-AUC Score: {rf_train_auc}')
# Out:
# Random Forest - Training Evaluation:
#
#
# Accuracy: 0.8729323518710291
# F1 Score: 0.9236538526216662
# ROC-AUC Score: 0.9396065774481757

# %%
# Evaluate on test data
rf_test_pred = grid_rand_forest.predict(X_test)
rf_test_pred_proba = grid_rand_forest.predict_proba(X_test)[:, 1]


rf_test_accuracy = accuracy_score(y_test, rf_test_pred)
rf_test_f1 = f1_score(y_test, rf_test_pred)
rf_test_auc = roc_auc_score(y_test, rf_test_pred_proba)


print("Random Forest - Testing Evaluation:\n\n")
print(f'Accuracy: {rf_test_accuracy}')
print(f'F1 Score: {rf_test_f1}')
print(f'ROC-AUC Score: {rf_test_auc}')
# Out:
# Random Forest - Testing Evaluation:
#
#
# Accuracy: 0.8628616208450336
# F1 Score: 0.9178981937602627
# ROC-AUC Score: 0.925788392431409

# %%
# To retest our function
best_rf_params = grid_rand_forest.best_params_
print("Best Hyperparameters:", best_rf_params)
print('\n\n')
# Access the best estimator
best_rf_model = grid_rand_forest.best_estimator_
best_rf_model
# Out:
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# RandomForestClassifier(max_depth=10)

# %%
plot_feature_importances(best_rf_model, X.columns)

# %% [markdown]
# ## Scaling the data

# %% [markdown]
# We will now get the data scaled for using other models

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51042 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   votes                51042 non-null  int64
#  1   couple_cost          51042 non-null  float64
#  2   online_encoded       51042 non-null  int32
#  3   book_encoded         51042 non-null  int32
#  4   location_encoded     51042 non-null  float64
#  5   rest_type_encoded    51042 non-null  float64
#  6   listed_type_encoded  51042 non-null  float64
#  7   city_encoded         51042 non-null  float64
#  8   biryani              51042 non-null  int32
#  9   chinese              51042 non-null  int32
#  10  fast food            51042 non-null  int32
#  11  north indian         51042 non-null  int32
#  12  other                51042 non-null  int32
#  13  south indian         51042 non-null  int32
# dtypes: float64(5), int32(8), int64(1)
# memory usage: 4.3 MB

# %%
std_scaler = StandardScaler()
X_train_scaled = std_scaler.fit_transform(X_train)
X_test_scaled = std_scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.11228865, -0.35288947,  0.82832695, ...,  1.20417797,
#         -1.50936764, -0.44686057],
#        [ 5.53698702,  1.69045227,  0.82832695, ...,  1.20417797,
#          0.66252911, -0.44686057],
#        [-0.33750054, -1.03400339,  0.82832695, ..., -0.83044203,
#         -1.50936764,  2.23783448],
#        ...,
#        [ 1.66536696,  2.14452821, -1.20725277, ..., -0.83044203,
#         -1.50936764,  2.23783448],
#        [ 2.12970832,  1.00933835,  0.82832695, ...,  1.20417797,
#          0.66252911, -0.44686057],
#        [ 0.80500695,  0.55526241, -1.20725277, ...,  1.20417797,
#         -1.50936764, -0.44686057]])

# %%
X_test_scaled
# Out:
# array([[-0.34762242, -0.35288947,  0.82832695, ..., -0.83044203,
#          0.66252911, -0.44686057],
#        [-0.35521383, -0.46640846, -1.20725277, ..., -0.83044203,
#          0.66252911, -0.44686057],
#        [-0.35015289, -0.46640846,  0.82832695, ..., -0.83044203,
#          0.66252911, -0.44686057],
#        ...,
#        [-0.10216677,  2.37156618,  0.82832695, ..., -0.83044203,
#          0.66252911, -0.44686057],
#        [-0.22995554,  0.10118647, -1.20725277, ..., -0.83044203,
#          0.66252911, -0.44686057],
#        [-0.34129624, -0.9204844 , -1.20725277, ..., -0.83044203,
#          0.66252911, -0.44686057]])

# %% [markdown]
# ## Non-Tree Models

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression
log_reg = LogisticRegression()
param_grid_log_reg = {
    'C': [0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']
}

# %%
# Perform GridSearchCV
grid_search = GridSearchCV(log_reg, param_grid_log_reg, cv=5)
start_time = time.time()
grid_search.fit(X_train_scaled, y_train)
end_time = time.time()
log_elapsed_time = end_time - start_time

# %%
log_elapsed_time
# Out:
# 3.547245979309082

# %%
best_log_model = grid_search.best_estimator_
print(best_log_model)
print('\n\n')

best_log_params = grid_search.best_params_
# Out:
# LogisticRegression(C=100, solver='liblinear')

# %%
# Evaluate on training data
log_train_pred = best_log_model.predict(X_train_scaled)
log_train_pred_proba = best_log_model.predict_proba(X_train_scaled)[:, 1]


log_train_accuracy = accuracy_score(y_train, log_train_pred)
log_train_f1 = f1_score(y_train, log_train_pred)
log_train_auc = roc_auc_score(y_train, log_train_pred_proba)

print("Logistic Regression - Training Evaluation:\n\n")
print(f'Accuracy: {log_train_accuracy}')
print(f'F1 Score: {log_train_f1}')
print(f'ROC-AUC Score: {log_train_auc}')
# Out:
# Logistic Regression - Training Evaluation:
#
#
# Accuracy: 0.7763161577430099
# F1 Score: 0.8737640183225399
# ROC-AUC Score: 0.7049472781017432

# %%
# Evaluate on test data
log_test_pred = best_log_model.predict(X_test_scaled)
log_test_pred_proba = best_log_model.predict_proba(X_test_scaled)[:, 1]


log_test_accuracy = accuracy_score(y_test, log_test_pred)
log_test_f1 = f1_score(y_test, log_test_pred)
log_test_auc = roc_auc_score(y_test, log_test_pred_proba)

print("Logistic Regression - Testing Evaluation:\n\n")
print(f'Accuracy: {log_test_accuracy}')
print(f'F1 Score: {log_test_f1}')
print(f'ROC-AUC Score: {log_test_auc}')
# Out:
# Logistic Regression - Testing Evaluation:
#
#
# Accuracy: 0.7761379220270358
# F1 Score: 0.8737291881538235
# ROC-AUC Score: 0.7079204519190527

# %% [markdown]
# Seems that ***Logistic Regression*** won't be our best selection for this task.

# %% [markdown]
# ## Comparing all models

# %%
# Combine metrics into a DataFrame
results_df = pd.DataFrame({
    'Model': ['Decision Tree', 'Random Forest', 'Logistic Regression'],
    'Train Accuracy': [dt_train_accuracy, rf_train_accuracy, log_train_accuracy],
    'Test Accuracy': [dt_test_accuracy, rf_test_accuracy, log_test_accuracy],
    'Train F1 Score': [dt_train_f1, rf_train_f1, log_train_f1],
    'Test F1 Score': [dt_test_f1, rf_test_f1, log_test_f1],
    'Train ROC AUC Score': [dt_train_auc, rf_train_auc, log_train_auc],
    'Test ROC AUC Score': [dt_test_auc, rf_test_auc, log_test_auc],
    'Elapsed Time (s)': [dt_elapsed_time, rf_elapsed_time, log_elapsed_time]
})

results_df
# Out:
#                  Model  Train Accuracy  Test Accuracy  Train F1 Score  \
# 0        Decision Tree        0.899381       0.882845        0.937616
# 1        Random Forest        0.872932       0.862862        0.923654
# 2  Logistic Regression        0.776316       0.776138        0.873764
#
#    Test F1 Score  Train ROC AUC Score  Test ROC AUC Score  Elapsed Time (s)
# 0       0.927451             0.947941            0.918710          6.569110
# 1       0.917898             0.939607            0.925788        343.411739
# 2       0.873729             0.704947            0.707920          3.547246

# %% [markdown]
# It's more than obvious that our decision should go for the ***Decision Tree***.
#
# Not only for it's optimum performance on both *Training* and *Testing* sets, but also for the big difference between it and *Random Forest* in terms of *Computing Time*.

# %% [markdown]
# ## One Final Enhancement Trial

# %% [markdown]
# Since we have settled for ***Decision Tree***, let's have a final attempt to improve it further, using ***Bagging*** technique.

# %%
from sklearn.ensemble import BaggingClassifier

# %%
# Create a BaggingClassifier using the Decision Tree as the base estimator
bagging_clf = BaggingClassifier(estimator=dec_tree, n_estimators=50, random_state=42)

# %%
# Train the BaggingClassifier on the training data
bagging_clf.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50,
#                   random_state=42)

# %%
# Make predictions on the test data
y_pred = bagging_clf.predict(X_test)

# %%
# Evaluate Bagging Model
bag_train_pred = bagging_clf.predict(X_train)
bag_train_pred_proba = bagging_clf.predict_proba(X_train)[:, 1]

bagging_train_accuracy = accuracy_score(y_train, bag_train_pred)
bagging_train_f1 = f1_score(y_train, bag_train_pred)
bagging_train_auc = roc_auc_score(y_train, bag_train_pred_proba)


print("Bagging Classifier - Training Evaluation:")
print(f'Accuracy: {bagging_train_accuracy}')
print(f'F1 Score: {bagging_train_f1}')
print(f'ROC-AUC Score: {bagging_train_auc}\n')
# Out:
# Bagging Classifier - Training Evaluation:
# Accuracy: 0.9996921268437404
# F1 Score: 0.9998021689477187
# ROC-AUC Score: 0.9999993806892876

# %%
bag_test_pred = bagging_clf.predict(X_test)
bag_test_pred_proba = bagging_clf.predict_proba(X_test)[:, 1]


bagging_test_accuracy = accuracy_score(y_test, bag_test_pred)
bagging_test_f1 = f1_score(y_test, bag_test_pred)
bagging_test_auc = roc_auc_score(y_test, bag_test_pred_proba)


print("Bagging Classifier - Testing Evaluation:")
print(f'Accuracy: {bagging_test_accuracy}')
print(f'F1 Score: {bagging_test_f1}')
print(f'ROC-AUC Score: {bagging_test_auc}\n')
# Out:
# Bagging Classifier - Testing Evaluation:
# Accuracy: 0.9631685495983805
# F1 Score: 0.9765176117911566
# ROC-AUC Score: 0.9892446331241325

# %% [markdown]
# **This is almost perfection!**

# %% [markdown]
# ## Plotting it all

# %%
# Plot ROC Curves
plt.figure(figsize=(10, 6))

# Compute ROC Curve for each model
for model_name, train_proba, test_proba in zip(
    ["Decision Tree", "Random Forest", "Logistic Regression", "Bagging"],
    [dt_train_pred_proba, rf_train_pred_proba, log_train_pred_proba, bag_train_pred_proba],
    [dt_test_pred_proba, rf_test_pred_proba, log_test_pred_proba, bag_test_pred_proba]):
    
    fpr, tpr, _ = roc_curve(y_test, test_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend()
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Finally, the best Classifier to work with on this dataset was ***Bagging Classifier*** with ***Decision Tree*** as its estimator. It clearly helped us predicting whether a new restaurant will be successful, in terms of rates. We have used a success threshold of **3.5** as a reasonable rating for considering a restaurant popular! However, we had this stored as a variable so that it can fit different business perspectives.
